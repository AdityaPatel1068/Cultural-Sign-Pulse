# %% [markdown]
# Steps to Process Videos
# Traverse Directories: Recursively explore all subdirectories to locate video files.
#
# Preprocess Each Video:
#
# Normalize FPS.
# Resize frames.
# Convert to tensor format.
# Save Output: Save the preprocessed video tensors to .pt files in a structured output directory mirroring the input hierarchy.

# %%
import os
import cv2
import torch
import numpy as np

# Base directory paths
base_path = r"D:\ASL\Dataset"
sub_dirs = ["train", "test", "val"]

# Target properties for preprocessing
TARGET_FPS = 30
TARGET_SIZE = (224, 224)
OUTPUT_DIR = r"D:\ASL\ProcessedDataset"

# Ensure the output directory exists
os.makedirs(OUTPUT_DIR, exist_ok=True)

# Function to normalize FPS and resize frames
def preprocess_video(video_path, target_fps=TARGET_FPS, target_size=TARGET_SIZE):
    cap = cv2.VideoCapture(video_path)
    original_fps = int(cap.get(cv2.CAP_PROP_FPS))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    duration = frame_count / original_fps

    # Calculate target frame count
    target_frame_count = int(duration * target_fps)
    frames = []

    for i in range(target_frame_count):
        cap.set(cv2.CAP_PROP_POS_FRAMES, i * original_fps / target_fps)
        ret, frame = cap.read()
        if ret:
            # Resize frame
            resized_frame = cv2.resize(frame, target_size)
            frames.append(resized_frame)
    cap.release()

    # Convert frames to tensor
    frames_tensor = torch.tensor(np.array(frames), dtype=torch.float32).permute(0, 3, 1, 2) / 255.0
    return frames_tensor

# Function to process and save videos
def process_videos(base_path, sub_dirs, output_dir):
    for sub_dir in sub_dirs:
        sub_dir_path = os.path.join(base_path, sub_dir)
        for root, _, files in os.walk(sub_dir_path):
            for file in files:
                if file.endswith((".mp4", ".avi", ".mov")):  # Add other formats as needed
                    video_path = os.path.join(root, file)
                    print(f"Processing: {video_path}")

                    # Preprocess video
                    try:
                        frames_tensor = preprocess_video(video_path)
                        # Save processed tensor
                        relative_path = os.path.relpath(root, base_path)
                        output_path = os.path.join(output_dir, relative_path)
                        os.makedirs(output_path, exist_ok=True)

                        tensor_path = os.path.join(output_path, f"{os.path.splitext(file)[0]}.pt")
                        torch.save(frames_tensor, tensor_path)
                        print(f"Saved processed video to: {tensor_path}")
                    except Exception as e:
                        print(f"Error processing {video_path}: {e}")

# Run the processing
process_videos(base_path, sub_dirs, OUTPUT_DIR)
# Out:
# Processing: D:\ASL\Dataset\train\#asl\#asl.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\#asl\#asl.pt
# Processing: D:\ASL\Dataset\train\#asl\#asl_blurred.mp4
# Error processing D:\ASL\Dataset\train\#asl\#asl_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#asl\#asl_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\#asl\#asl_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#asl\#asl_flipped.mp4
# Error processing D:\ASL\Dataset\train\#asl\#asl_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#asl\#asl_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\#asl\#asl_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#asl\#asl_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\#asl\#asl_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#asl\#asl_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\#asl\#asl_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#asl\#asl_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\#asl\#asl_rotated.pt
# Processing: D:\ASL\Dataset\train\#asl\temp_#asl_rotated.avi
# Saved processed video to: D:\ASL\ProcessedDataset\train\#asl\temp_#asl_rotated.pt
# Processing: D:\ASL\Dataset\train\#ok\#ok.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\#ok\#ok.pt
# Processing: D:\ASL\Dataset\train\#ok\#ok_blurred.mp4
# Error processing D:\ASL\Dataset\train\#ok\#ok_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#ok\#ok_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\#ok\#ok_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#ok\#ok_flipped.mp4
# Error processing D:\ASL\Dataset\train\#ok\#ok_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#ok\#ok_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\#ok\#ok_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#ok\#ok_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\#ok\#ok_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#ok\#ok_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\#ok\#ok_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\#ok\#ok_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\#ok\#ok_rotated.pt
# Processing: D:\ASL\Dataset\train\21\21.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\21\21.pt
# Processing: D:\ASL\Dataset\train\21\21_blurred.mp4
# Error processing D:\ASL\Dataset\train\21\21_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\21\21_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\21\21_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\21\21_flipped.mp4
# Error processing D:\ASL\Dataset\train\21\21_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\21\21_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\21\21_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\21\21_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\21\21_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\21\21_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\21\21_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\21\21_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\21\21_rotated.pt
# Processing: D:\ASL\Dataset\train\22\22.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\22\22.pt
# Processing: D:\ASL\Dataset\train\22\22_blurred.mp4
# Error processing D:\ASL\Dataset\train\22\22_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\22\22_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\22\22_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\22\22_flipped.mp4
# Error processing D:\ASL\Dataset\train\22\22_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\22\22_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\22\22_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\22\22_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\22\22_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\22\22_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\22\22_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\22\22_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\22\22_rotated.pt
# Processing: D:\ASL\Dataset\train\23\23.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\23\23.pt
# Processing: D:\ASL\Dataset\train\23\23_blurred.mp4
# Error processing D:\ASL\Dataset\train\23\23_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\23\23_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\23\23_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\23\23_flipped.mp4
# Error processing D:\ASL\Dataset\train\23\23_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\23\23_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\23\23_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\23\23_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\23\23_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\23\23_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\23\23_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\23\23_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\23\23_rotated.pt
# Processing: D:\ASL\Dataset\train\24\24.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\24\24.pt
# Processing: D:\ASL\Dataset\train\24\24_blurred.mp4
# Error processing D:\ASL\Dataset\train\24\24_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\24\24_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\24\24_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\24\24_flipped.mp4
# Error processing D:\ASL\Dataset\train\24\24_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\24\24_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\24\24_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\24\24_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\24\24_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\24\24_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\24\24_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\24\24_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\24\24_rotated.pt
# Processing: D:\ASL\Dataset\train\25\25.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\25\25.pt
# Processing: D:\ASL\Dataset\train\25\25_blurred.mp4
# Error processing D:\ASL\Dataset\train\25\25_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\25\25_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\25\25_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\25\25_flipped.mp4
# Error processing D:\ASL\Dataset\train\25\25_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\25\25_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\25\25_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\25\25_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\25\25_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\25\25_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\25\25_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\25\25_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\25\25_rotated.pt
# Processing: D:\ASL\Dataset\train\26\26.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\26\26.pt
# Processing: D:\ASL\Dataset\train\26\26_blurred.mp4
# Error processing D:\ASL\Dataset\train\26\26_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\26\26_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\26\26_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\26\26_flipped.mp4
# Error processing D:\ASL\Dataset\train\26\26_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\26\26_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\26\26_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\26\26_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\26\26_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\26\26_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\26\26_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\26\26_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\26\26_rotated.pt
# Processing: D:\ASL\Dataset\train\27\27.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\27\27.pt
# Processing: D:\ASL\Dataset\train\27\27_blurred.mp4
# Error processing D:\ASL\Dataset\train\27\27_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\27\27_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\27\27_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\27\27_flipped.mp4
# Error processing D:\ASL\Dataset\train\27\27_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\27\27_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\27\27_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\27\27_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\27\27_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\27\27_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\27\27_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\27\27_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\27\27_rotated.pt
# Processing: D:\ASL\Dataset\train\28\28.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\28\28.pt
# Processing: D:\ASL\Dataset\train\28\28_blurred.mp4
# Error processing D:\ASL\Dataset\train\28\28_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\28\28_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\28\28_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\28\28_flipped.mp4
# Error processing D:\ASL\Dataset\train\28\28_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\28\28_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\28\28_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\28\28_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\28\28_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\28\28_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\28\28_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\28\28_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\28\28_rotated.pt
# Processing: D:\ASL\Dataset\train\29\29.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\29\29.pt
# Processing: D:\ASL\Dataset\train\29\29_blurred.mp4
# Error processing D:\ASL\Dataset\train\29\29_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\29\29_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\29\29_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\29\29_flipped.mp4
# Error processing D:\ASL\Dataset\train\29\29_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\29\29_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\29\29_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\29\29_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\29\29_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\29\29_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\29\29_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\29\29_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\29\29_rotated.pt
# Processing: D:\ASL\Dataset\train\30\30.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\30\30.pt
# Processing: D:\ASL\Dataset\train\30\30_blurred.mp4
# Error processing D:\ASL\Dataset\train\30\30_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\30\30_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\30\30_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\30\30_flipped.mp4
# Error processing D:\ASL\Dataset\train\30\30_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\30\30_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\30\30_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\30\30_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\30\30_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\30\30_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\30\30_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\30\30_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\30\30_rotated.pt
# Processing: D:\ASL\Dataset\train\50\50.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\50\50.pt
# Processing: D:\ASL\Dataset\train\50\50_blurred.mp4
# Error processing D:\ASL\Dataset\train\50\50_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\50\50_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\50\50_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\50\50_flipped.mp4
# Error processing D:\ASL\Dataset\train\50\50_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\50\50_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\50\50_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\50\50_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\50\50_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\50\50_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\50\50_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\50\50_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\50\50_rotated.pt
# Processing: D:\ASL\Dataset\train\about\about.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\about\about.pt
# Processing: D:\ASL\Dataset\train\about\about_blurred.mp4
# Error processing D:\ASL\Dataset\train\about\about_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\about\about_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\about\about_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\about\about_flipped.mp4
# Error processing D:\ASL\Dataset\train\about\about_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\about\about_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\about\about_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\about\about_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\about\about_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\about\about_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\about\about_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\about\about_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\about\about_rotated.pt
# Processing: D:\ASL\Dataset\train\absent\absent.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\absent\absent.pt
# Processing: D:\ASL\Dataset\train\absent\absent_blurred.mp4
# Error processing D:\ASL\Dataset\train\absent\absent_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\absent\absent_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\absent\absent_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\absent\absent_flipped.mp4
# Error processing D:\ASL\Dataset\train\absent\absent_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\absent\absent_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\absent\absent_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\absent\absent_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\absent\absent_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\absent\absent_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\absent\absent_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\absent\absent_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\absent\absent_rotated.pt
# Processing: D:\ASL\Dataset\train\accept\accept.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\accept\accept.pt
# Processing: D:\ASL\Dataset\train\accept\accept_blurred.mp4
# Error processing D:\ASL\Dataset\train\accept\accept_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accept\accept_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\accept\accept_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accept\accept_flipped.mp4
# Error processing D:\ASL\Dataset\train\accept\accept_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accept\accept_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\accept\accept_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accept\accept_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\accept\accept_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accept\accept_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\accept\accept_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accept\accept_rotated.mp4
# Error processing D:\ASL\Dataset\train\accept\accept_rotated.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accident\accident.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\accident\accident.pt
# Processing: D:\ASL\Dataset\train\accident\accident_blurred.mp4
# Error processing D:\ASL\Dataset\train\accident\accident_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accident\accident_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\accident\accident_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accident\accident_flipped.mp4
# Error processing D:\ASL\Dataset\train\accident\accident_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accident\accident_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\accident\accident_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accident\accident_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\accident\accident_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accident\accident_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\accident\accident_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accident\accident_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\accident\accident_rotated.pt
# Processing: D:\ASL\Dataset\train\accountant\accountant.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\accountant\accountant.pt
# Processing: D:\ASL\Dataset\train\accountant\accountant_blurred.mp4
# Error processing D:\ASL\Dataset\train\accountant\accountant_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accountant\accountant_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\accountant\accountant_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accountant\accountant_flipped.mp4
# Error processing D:\ASL\Dataset\train\accountant\accountant_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accountant\accountant_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\accountant\accountant_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accountant\accountant_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\accountant\accountant_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accountant\accountant_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\accountant\accountant_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\accountant\accountant_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\accountant\accountant_rotated.pt
# Processing: D:\ASL\Dataset\train\acquire\acquire.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\acquire\acquire.pt
# Processing: D:\ASL\Dataset\train\acquire\acquire_blurred.mp4
# Error processing D:\ASL\Dataset\train\acquire\acquire_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\acquire\acquire_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\acquire\acquire_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\acquire\acquire_flipped.mp4
# Error processing D:\ASL\Dataset\train\acquire\acquire_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\acquire\acquire_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\acquire\acquire_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\acquire\acquire_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\acquire\acquire_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\acquire\acquire_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\acquire\acquire_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\acquire\acquire_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\acquire\acquire_rotated.pt
# Processing: D:\ASL\Dataset\train\actor\actor.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\actor\actor.pt
# Processing: D:\ASL\Dataset\train\actor\actor_blurred.mp4
# Error processing D:\ASL\Dataset\train\actor\actor_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\actor\actor_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\actor\actor_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\actor\actor_flipped.mp4
# Error processing D:\ASL\Dataset\train\actor\actor_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\actor\actor_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\actor\actor_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\actor\actor_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\actor\actor_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\actor\actor_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\actor\actor_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\actor\actor_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\actor\actor_rotated.pt
# Processing: D:\ASL\Dataset\train\adopt\adopt.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\adopt\adopt.pt
# Processing: D:\ASL\Dataset\train\adopt\adopt_blurred.mp4
# Error processing D:\ASL\Dataset\train\adopt\adopt_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adopt\adopt_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\adopt\adopt_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adopt\adopt_flipped.mp4
# Error processing D:\ASL\Dataset\train\adopt\adopt_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adopt\adopt_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\adopt\adopt_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adopt\adopt_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\adopt\adopt_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adopt\adopt_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\adopt\adopt_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adopt\adopt_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\adopt\adopt_rotated.pt
# Processing: D:\ASL\Dataset\train\adult\adult.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\adult\adult.pt
# Processing: D:\ASL\Dataset\train\adult\adult_blurred.mp4
# Error processing D:\ASL\Dataset\train\adult\adult_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adult\adult_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\adult\adult_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adult\adult_flipped.mp4
# Error processing D:\ASL\Dataset\train\adult\adult_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adult\adult_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\adult\adult_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adult\adult_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\adult\adult_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adult\adult_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\adult\adult_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\adult\adult_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\adult\adult_rotated.pt
# Processing: D:\ASL\Dataset\train\afraid\afraid.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\afraid\afraid.pt
# Processing: D:\ASL\Dataset\train\afraid\afraid_blurred.mp4
# Error processing D:\ASL\Dataset\train\afraid\afraid_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afraid\afraid_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\afraid\afraid_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afraid\afraid_flipped.mp4
# Error processing D:\ASL\Dataset\train\afraid\afraid_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afraid\afraid_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\afraid\afraid_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afraid\afraid_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\afraid\afraid_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afraid\afraid_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\afraid\afraid_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afraid\afraid_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\afraid\afraid_rotated.pt
# Processing: D:\ASL\Dataset\train\africa\africa.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\africa\africa.pt
# Processing: D:\ASL\Dataset\train\africa\africa_blurred.mp4
# Error processing D:\ASL\Dataset\train\africa\africa_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\africa\africa_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\africa\africa_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\africa\africa_flipped.mp4
# Error processing D:\ASL\Dataset\train\africa\africa_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\africa\africa_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\africa\africa_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\africa\africa_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\africa\africa_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\africa\africa_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\africa\africa_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\africa\africa_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\africa\africa_rotated.pt
# Processing: D:\ASL\Dataset\train\after\after.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\after\after.pt
# Processing: D:\ASL\Dataset\train\after\after_blurred.mp4
# Error processing D:\ASL\Dataset\train\after\after_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\after\after_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\after\after_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\after\after_flipped.mp4
# Error processing D:\ASL\Dataset\train\after\after_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\after\after_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\after\after_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\after\after_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\after\after_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\after\after_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\after\after_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\after\after_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\after\after_rotated.pt
# Processing: D:\ASL\Dataset\train\afternoon\afternoon.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\afternoon\afternoon.pt
# Processing: D:\ASL\Dataset\train\afternoon\afternoon_blurred.mp4
# Error processing D:\ASL\Dataset\train\afternoon\afternoon_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afternoon\afternoon_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\afternoon\afternoon_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afternoon\afternoon_flipped.mp4
# Error processing D:\ASL\Dataset\train\afternoon\afternoon_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afternoon\afternoon_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\afternoon\afternoon_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afternoon\afternoon_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\afternoon\afternoon_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afternoon\afternoon_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\afternoon\afternoon_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\afternoon\afternoon_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\afternoon\afternoon_rotated.pt
# Processing: D:\ASL\Dataset\train\again\again.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\again\again.pt
# Processing: D:\ASL\Dataset\train\again\again_blurred.mp4
# Error processing D:\ASL\Dataset\train\again\again_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\again\again_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\again\again_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\again\again_flipped.mp4
# Error processing D:\ASL\Dataset\train\again\again_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\again\again_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\again\again_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\again\again_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\again\again_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\again\again_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\again\again_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\again\again_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\again\again_rotated.pt
# Processing: D:\ASL\Dataset\train\airplane\airplane.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\airplane\airplane.pt
# Processing: D:\ASL\Dataset\train\airplane\airplane_blurred.mp4
# Error processing D:\ASL\Dataset\train\airplane\airplane_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\airplane\airplane_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\airplane\airplane_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\airplane\airplane_flipped.mp4
# Error processing D:\ASL\Dataset\train\airplane\airplane_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\airplane\airplane_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\airplane\airplane_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\airplane\airplane_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\airplane\airplane_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\airplane\airplane_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\airplane\airplane_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\airplane\airplane_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\airplane\airplane_rotated.pt
# Processing: D:\ASL\Dataset\train\alarm\alarm.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\alarm\alarm.pt
# Processing: D:\ASL\Dataset\train\alarm\alarm_blurred.mp4
# Error processing D:\ASL\Dataset\train\alarm\alarm_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alarm\alarm_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\alarm\alarm_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alarm\alarm_flipped.mp4
# Error processing D:\ASL\Dataset\train\alarm\alarm_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alarm\alarm_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\alarm\alarm_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alarm\alarm_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\alarm\alarm_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alarm\alarm_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\alarm\alarm_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alarm\alarm_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\alarm\alarm_rotated.pt
# Processing: D:\ASL\Dataset\train\algebra\algebra.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\algebra\algebra.pt
# Processing: D:\ASL\Dataset\train\algebra\algebra_blurred.mp4
# Error processing D:\ASL\Dataset\train\algebra\algebra_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\algebra\algebra_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\algebra\algebra_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\algebra\algebra_flipped.mp4
# Error processing D:\ASL\Dataset\train\algebra\algebra_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\algebra\algebra_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\algebra\algebra_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\algebra\algebra_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\algebra\algebra_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\algebra\algebra_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\algebra\algebra_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\algebra\algebra_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\algebra\algebra_rotated.pt
# Processing: D:\ASL\Dataset\train\all\all.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all\all.pt
# Processing: D:\ASL\Dataset\train\all\all_blurred.mp4
# Error processing D:\ASL\Dataset\train\all\all_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all\all_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\all\all_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all\all_flipped.mp4
# Error processing D:\ASL\Dataset\train\all\all_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all\all_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\all\all_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all\all_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\all\all_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all\all_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\all\all_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all\all_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all\all_rotated.pt
# Processing: D:\ASL\Dataset\train\all day\all day.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all day\all day.pt
# Processing: D:\ASL\Dataset\train\all day\all day_blurred.mp4
# Error processing D:\ASL\Dataset\train\all day\all day_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all day\all day_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\all day\all day_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all day\all day_flipped.mp4
# Error processing D:\ASL\Dataset\train\all day\all day_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all day\all day_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\all day\all day_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all day\all day_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\all day\all day_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all day\all day_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\all day\all day_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all day\all day_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all day\all day_rotated.pt
# Processing: D:\ASL\Dataset\train\all morning\all morning.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all morning\all morning.pt
# Processing: D:\ASL\Dataset\train\all morning\all morning_blurred.mp4
# Error processing D:\ASL\Dataset\train\all morning\all morning_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all morning\all morning_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\all morning\all morning_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all morning\all morning_flipped.mp4
# Error processing D:\ASL\Dataset\train\all morning\all morning_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all morning\all morning_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\all morning\all morning_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all morning\all morning_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\all morning\all morning_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all morning\all morning_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\all morning\all morning_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all morning\all morning_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all morning\all morning_rotated.pt
# Processing: D:\ASL\Dataset\train\all night\all night.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all night\all night.pt
# Processing: D:\ASL\Dataset\train\all night\all night_blurred.mp4
# Error processing D:\ASL\Dataset\train\all night\all night_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all night\all night_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\all night\all night_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all night\all night_flipped.mp4
# Error processing D:\ASL\Dataset\train\all night\all night_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all night\all night_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\all night\all night_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all night\all night_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\all night\all night_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all night\all night_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\all night\all night_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\all night\all night_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\all night\all night_rotated.pt
# Processing: D:\ASL\Dataset\train\alone\alone.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\alone\alone.pt
# Processing: D:\ASL\Dataset\train\alone\alone_blurred.mp4
# Error processing D:\ASL\Dataset\train\alone\alone_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alone\alone_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\alone\alone_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alone\alone_flipped.mp4
# Error processing D:\ASL\Dataset\train\alone\alone_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alone\alone_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\alone\alone_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alone\alone_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\alone\alone_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alone\alone_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\alone\alone_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\alone\alone_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\alone\alone_rotated.pt
# Processing: D:\ASL\Dataset\train\also\also.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\also\also.pt
# Processing: D:\ASL\Dataset\train\also\also_blurred.mp4
# Error processing D:\ASL\Dataset\train\also\also_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\also\also_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\also\also_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\also\also_flipped.mp4
# Error processing D:\ASL\Dataset\train\also\also_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\also\also_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\also\also_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\also\also_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\also\also_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\also\also_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\also\also_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\also\also_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\also\also_rotated.pt
# Processing: D:\ASL\Dataset\train\always\always.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\always\always.pt
# Processing: D:\ASL\Dataset\train\always\always_blurred.mp4
# Error processing D:\ASL\Dataset\train\always\always_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\always\always_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\always\always_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\always\always_flipped.mp4
# Error processing D:\ASL\Dataset\train\always\always_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\always\always_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\always\always_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\always\always_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\always\always_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\always\always_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\always\always_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\always\always_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\always\always_rotated.pt
# Processing: D:\ASL\Dataset\train\america\america.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\america\america.pt
# Processing: D:\ASL\Dataset\train\america\america_blurred.mp4
# Error processing D:\ASL\Dataset\train\america\america_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\america\america_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\america\america_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\america\america_flipped.mp4
# Error processing D:\ASL\Dataset\train\america\america_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\america\america_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\america\america_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\america\america_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\america\america_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\america\america_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\america\america_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\america\america_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\america\america_rotated.pt
# Processing: D:\ASL\Dataset\train\and\and.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\and\and.pt
# Processing: D:\ASL\Dataset\train\and\and_blurred.mp4
# Error processing D:\ASL\Dataset\train\and\and_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\and\and_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\and\and_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\and\and_flipped.mp4
# Error processing D:\ASL\Dataset\train\and\and_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\and\and_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\and\and_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\and\and_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\and\and_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\and\and_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\and\and_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\and\and_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\and\and_rotated.pt
# Processing: D:\ASL\Dataset\train\angry\angry.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\angry\angry.pt
# Processing: D:\ASL\Dataset\train\angry\angry_blurred.mp4
# Error processing D:\ASL\Dataset\train\angry\angry_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\angry\angry_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\angry\angry_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\angry\angry_flipped.mp4
# Error processing D:\ASL\Dataset\train\angry\angry_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\angry\angry_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\angry\angry_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\angry\angry_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\angry\angry_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\angry\angry_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\angry\angry_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\angry\angry_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\angry\angry_rotated.pt
# Processing: D:\ASL\Dataset\train\animal\animal.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\animal\animal.pt
# Processing: D:\ASL\Dataset\train\animal\animal_blurred.mp4
# Error processing D:\ASL\Dataset\train\animal\animal_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\animal\animal_brightness_contrast.mp4
# Error processing D:\ASL\Dataset\train\animal\animal_brightness_contrast.mp4: division by zero
# Processing: D:\ASL\Dataset\train\animal\animal_flipped.mp4
# Error processing D:\ASL\Dataset\train\animal\animal_flipped.mp4: division by zero
# Processing: D:\ASL\Dataset\train\animal\animal_gaussian_noise.mp4
# Error processing D:\ASL\Dataset\train\animal\animal_gaussian_noise.mp4: division by zero
# Processing: D:\ASL\Dataset\train\animal\animal_hue_saturation_shift.mp4
# Error processing D:\ASL\Dataset\train\animal\animal_hue_saturation_shift.mp4: division by zero
# Processing: D:\ASL\Dataset\train\animal\animal_perspective_warp.mp4
# Error processing D:\ASL\Dataset\train\animal\animal_perspective_warp.mp4: division by zero
# Processing: D:\ASL\Dataset\train\animal\animal_rotated.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\animal\animal_rotated.pt
# Processing: D:\ASL\Dataset\train\annoy\annoy.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\train\annoy\annoy.pt
# Processing: D:\ASL\Dataset\train\annoy\annoy_blurred.mp4
# Error processing D:\ASL\Dataset\train\annoy\annoy_blurred.mp4: division by zero
# Processing: D:\ASL\Dataset\train\annoy\annoy_brightness_contrast.mp4
# ...
# Saved processed video to: D:\ASL\ProcessedDataset\val\question\question.pt
# Processing: D:\ASL\Dataset\val\quiet\quiet.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\quiet\quiet.pt
# Processing: D:\ASL\Dataset\val\rainbow\rainbow.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\rainbow\rainbow.pt
# Processing: D:\ASL\Dataset\val\read\read.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\read\read.pt
# Processing: D:\ASL\Dataset\val\ready\ready.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\ready\ready.pt
# Processing: D:\ASL\Dataset\val\red\red.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\red\red.pt
# Processing: D:\ASL\Dataset\val\relationship\relationship.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\relationship\relationship.pt
# Processing: D:\ASL\Dataset\val\remember\remember.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\remember\remember.pt
# Processing: D:\ASL\Dataset\val\right\right.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\right\right.pt
# Processing: D:\ASL\Dataset\val\rude\rude.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\rude\rude.pt
# Processing: D:\ASL\Dataset\val\russia\russia.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\russia\russia.pt
# Processing: D:\ASL\Dataset\val\sad\sad.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sad\sad.pt
# Processing: D:\ASL\Dataset\val\salad\salad.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\salad\salad.pt
# Processing: D:\ASL\Dataset\val\salt\salt.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\salt\salt.pt
# Processing: D:\ASL\Dataset\val\same\same.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\same\same.pt
# Processing: D:\ASL\Dataset\val\sandwich\sandwich.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sandwich\sandwich.pt
# Processing: D:\ASL\Dataset\val\school\school.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\school\school.pt
# Processing: D:\ASL\Dataset\val\science\science.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\science\science.pt
# Processing: D:\ASL\Dataset\val\seem\seem.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\seem\seem.pt
# Processing: D:\ASL\Dataset\val\serious\serious.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\serious\serious.pt
# Processing: D:\ASL\Dataset\val\sew\sew.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sew\sew.pt
# Processing: D:\ASL\Dataset\val\shark\shark.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\shark\shark.pt
# Processing: D:\ASL\Dataset\val\shirt\shirt.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\shirt\shirt.pt
# Processing: D:\ASL\Dataset\val\shock\shock.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\shock\shock.pt
# Processing: D:\ASL\Dataset\val\shoes\shoes.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\shoes\shoes.pt
# Processing: D:\ASL\Dataset\val\short\short.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\short\short.pt
# Processing: D:\ASL\Dataset\val\shrimp\shrimp.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\shrimp\shrimp.pt
# Processing: D:\ASL\Dataset\val\shy\shy.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\shy\shy.pt
# Processing: D:\ASL\Dataset\val\sick\sick.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sick\sick.pt
# Processing: D:\ASL\Dataset\val\sign\sign.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sign\sign.pt
# Processing: D:\ASL\Dataset\val\silver\silver.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\silver\silver.pt
# Processing: D:\ASL\Dataset\val\single\single.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\single\single.pt
# Processing: D:\ASL\Dataset\val\sit\sit.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sit\sit.pt
# Processing: D:\ASL\Dataset\val\skirt\skirt.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\skirt\skirt.pt
# Processing: D:\ASL\Dataset\val\sleep\sleep.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sleep\sleep.pt
# Processing: D:\ASL\Dataset\val\sleepy\sleepy.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sleepy\sleepy.pt
# Processing: D:\ASL\Dataset\val\slide\slide.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\slide\slide.pt
# Processing: D:\ASL\Dataset\val\slow\slow.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\slow\slow.pt
# Processing: D:\ASL\Dataset\val\snake\snake.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\snake\snake.pt
# Processing: D:\ASL\Dataset\val\sneeze\sneeze.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sneeze\sneeze.pt
# Processing: D:\ASL\Dataset\val\so\so.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\so\so.pt
# Processing: D:\ASL\Dataset\val\soap\soap.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\soap\soap.pt
# Processing: D:\ASL\Dataset\val\socks\socks.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\socks\socks.pt
# Processing: D:\ASL\Dataset\val\soda\soda.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\soda\soda.pt
# Processing: D:\ASL\Dataset\val\some\some.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\some\some.pt
# Processing: D:\ASL\Dataset\val\sophomore\sophomore.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sophomore\sophomore.pt
# Processing: D:\ASL\Dataset\val\sorry\sorry.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sorry\sorry.pt
# Processing: D:\ASL\Dataset\val\soup\soup.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\soup\soup.pt
# Processing: D:\ASL\Dataset\val\south\south.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\south\south.pt
# Processing: D:\ASL\Dataset\val\south africa\south africa.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\south africa\south africa.pt
# Processing: D:\ASL\Dataset\val\south america\south america.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\south america\south america.pt
# Processing: D:\ASL\Dataset\val\spaghetti\spaghetti.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\spaghetti\spaghetti.pt
# Processing: D:\ASL\Dataset\val\speech\speech.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\speech\speech.pt
# Processing: D:\ASL\Dataset\val\spider\spider.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\spider\spider.pt
# Processing: D:\ASL\Dataset\val\spoon\spoon.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\spoon\spoon.pt
# Processing: D:\ASL\Dataset\val\spring up\spring up.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\spring up\spring up.pt
# Processing: D:\ASL\Dataset\val\squirrel\squirrel.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\squirrel\squirrel.pt
# Processing: D:\ASL\Dataset\val\start\start.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\start\start.pt
# Processing: D:\ASL\Dataset\val\still\still.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\still\still.pt
# Processing: D:\ASL\Dataset\val\stop\stop.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\stop\stop.pt
# Processing: D:\ASL\Dataset\val\store\store.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\store\store.pt
# Processing: D:\ASL\Dataset\val\strange\strange.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\strange\strange.pt
# Processing: D:\ASL\Dataset\val\strict\strict.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\strict\strict.pt
# Processing: D:\ASL\Dataset\val\stubborn\stubborn.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\stubborn\stubborn.pt
# Processing: D:\ASL\Dataset\val\stuck\stuck.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\stuck\stuck.pt
# Processing: D:\ASL\Dataset\val\study\study.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\study\study.pt
# Processing: D:\ASL\Dataset\val\stupid\stupid.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\stupid\stupid.pt
# Processing: D:\ASL\Dataset\val\subway\subway.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\subway\subway.pt
# Processing: D:\ASL\Dataset\val\sun\sun.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sun\sun.pt
# Processing: D:\ASL\Dataset\val\sweater\sweater.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sweater\sweater.pt
# Processing: D:\ASL\Dataset\val\sweet\sweet.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\sweet\sweet.pt
# Processing: D:\ASL\Dataset\val\swimming\swimming.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\swimming\swimming.pt
# Processing: D:\ASL\Dataset\val\table\table.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\table\table.pt
# Processing: D:\ASL\Dataset\val\take up\take up.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\take up\take up.pt
# Processing: D:\ASL\Dataset\val\talk\talk.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\talk\talk.pt
# Processing: D:\ASL\Dataset\val\tall\tall.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tall\tall.pt
# Processing: D:\ASL\Dataset\val\tea\tea.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tea\tea.pt
# Processing: D:\ASL\Dataset\val\teach\teach.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\teach\teach.pt
# Processing: D:\ASL\Dataset\val\teacher\teacher.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\teacher\teacher.pt
# Processing: D:\ASL\Dataset\val\tell\tell.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tell\tell.pt
# Processing: D:\ASL\Dataset\val\that one\that one.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\that one\that one.pt
# Processing: D:\ASL\Dataset\val\there\there.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\there\there.pt
# Processing: D:\ASL\Dataset\val\they\they.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\they\they.pt
# Processing: D:\ASL\Dataset\val\thin\thin.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\thin\thin.pt
# Processing: D:\ASL\Dataset\val\thirsty\thirsty.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\thirsty\thirsty.pt
# Processing: D:\ASL\Dataset\val\tie\tie.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tie\tie.pt
# Processing: D:\ASL\Dataset\val\tiger\tiger.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tiger\tiger.pt
# Processing: D:\ASL\Dataset\val\time\time.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\time\time.pt
# Processing: D:\ASL\Dataset\val\tired\tired.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tired\tired.pt
# Processing: D:\ASL\Dataset\val\toast\toast.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\toast\toast.pt
# Processing: D:\ASL\Dataset\val\together\together.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\together\together.pt
# Processing: D:\ASL\Dataset\val\tomato\tomato.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tomato\tomato.pt
# Processing: D:\ASL\Dataset\val\towel\towel.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\towel\towel.pt
# Processing: D:\ASL\Dataset\val\train\train.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\train\train.pt
# Processing: D:\ASL\Dataset\val\transfer\transfer.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\transfer\transfer.pt
# Processing: D:\ASL\Dataset\val\travel\travel.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\travel\travel.pt
# Processing: D:\ASL\Dataset\val\tree\tree.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\tree\tree.pt
# Processing: D:\ASL\Dataset\val\trigonometry\trigonometry.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\trigonometry\trigonometry.pt
# Processing: D:\ASL\Dataset\val\true\true.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\true\true.pt
# Processing: D:\ASL\Dataset\val\turkey\turkey.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\turkey\turkey.pt
# Processing: D:\ASL\Dataset\val\twenty\twenty.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\twenty\twenty.pt
# Processing: D:\ASL\Dataset\val\ugly\ugly.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\ugly\ugly.pt
# Processing: D:\ASL\Dataset\val\umbrella\umbrella.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\umbrella\umbrella.pt
# Processing: D:\ASL\Dataset\val\understand\understand.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\understand\understand.pt
# Processing: D:\ASL\Dataset\val\university\university.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\university\university.pt
# Processing: D:\ASL\Dataset\val\up\up.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\up\up.pt
# Processing: D:\ASL\Dataset\val\vacation\vacation.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\vacation\vacation.pt
# Processing: D:\ASL\Dataset\val\vacuum\vacuum.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\vacuum\vacuum.pt
# Processing: D:\ASL\Dataset\val\vegetable\vegetable.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\vegetable\vegetable.pt
# Processing: D:\ASL\Dataset\val\wake up\wake up.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\wake up\wake up.pt
# Processing: D:\ASL\Dataset\val\walk\walk.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\walk\walk.pt
# Processing: D:\ASL\Dataset\val\want\want.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\want\want.pt
# Processing: D:\ASL\Dataset\val\warm\warm.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\warm\warm.pt
# Processing: D:\ASL\Dataset\val\watch\watch.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\watch\watch.pt
# Processing: D:\ASL\Dataset\val\water\water.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\water\water.pt
# Processing: D:\ASL\Dataset\val\watermelon\watermelon.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\watermelon\watermelon.pt
# Processing: D:\ASL\Dataset\val\weak\weak.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\weak\weak.pt
# Processing: D:\ASL\Dataset\val\welcome\welcome.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\welcome\welcome.pt
# Processing: D:\ASL\Dataset\val\wet\wet.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\wet\wet.pt
# Processing: D:\ASL\Dataset\val\whale\whale.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\whale\whale.pt
# Processing: D:\ASL\Dataset\val\what\what.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\what\what.pt
# Processing: D:\ASL\Dataset\val\when\when.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\when\when.pt
# Processing: D:\ASL\Dataset\val\white\white.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\white\white.pt
# Processing: D:\ASL\Dataset\val\why\why.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\why\why.pt
# Processing: D:\ASL\Dataset\val\win\win.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\win\win.pt
# Processing: D:\ASL\Dataset\val\wine\wine.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\wine\wine.pt
# Processing: D:\ASL\Dataset\val\with\with.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\with\with.pt
# Processing: D:\ASL\Dataset\val\wood\wood.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\wood\wood.pt
# Processing: D:\ASL\Dataset\val\worm\worm.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\worm\worm.pt
# Processing: D:\ASL\Dataset\val\worry\worry.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\worry\worry.pt
# Processing: D:\ASL\Dataset\val\wow\wow.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\wow\wow.pt
# Processing: D:\ASL\Dataset\val\wrong\wrong.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\wrong\wrong.pt
# Processing: D:\ASL\Dataset\val\year\year.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\year\year.pt
# Processing: D:\ASL\Dataset\val\yellow\yellow.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\yellow\yellow.pt
# Processing: D:\ASL\Dataset\val\yes\yes.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\yes\yes.pt
# Processing: D:\ASL\Dataset\val\young\young.mp4
# Saved processed video to: D:\ASL\ProcessedDataset\val\young\young.pt

# %% [markdown]
# Dataloader

# %%
import os
import torch
from torch.utils.data import Dataset

class ASLVideoDataset(Dataset):
    def __init__(self, base_path, sub_dirs, transform=None):
        """
        Custom Dataset for loading preprocessed video tensors.

        Args:
            base_path (str): Path to the processed dataset folder.
            sub_dirs (list): List of subdirectories (e.g., ["train", "test", "val"]).
            transform (callable, optional): Optional transformations on video tensors.
        """
        self.data = []
        self.labels = []
        self.transform = transform

        for sub_dir in sub_dirs:
            sub_dir_path = os.path.join(base_path, sub_dir)
            for root, _, files in os.walk(sub_dir_path):
                for file in files:
                    if file.endswith(".pt"):
                        file_path = os.path.join(root, file)
                        # Label is derived from the file name (e.g., "SIMILE" from "SIMILE.pt")
                        label = os.path.splitext(file)[0]
                        self.data.append(file_path)
                        self.labels.append(label)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        # Load tensor
        video_tensor = torch.load(self.data[idx])
        label = self.labels[idx]

        # Apply transformation if provided
        if self.transform:
            video_tensor = self.transform(video_tensor)

        return video_tensor, label

# %%
from torchvision.transforms import Compose, Normalize

# Example normalization (adjust mean and std based on your dataset)
transform = Compose([
    Normalize(mean=[0.5], std=[0.5])  # Example: normalize pixel values
])

# %%
from torch.utils.data import DataLoader

# Paths
base_path = r"D:\ASL\ProcessedDataset"
sub_dirs = ["train", "test", "val"]

# Instantiate Dataset for training, testing, and validation
train_dataset = ASLVideoDataset(base_path, ["train"], transform=transform)
test_dataset = ASLVideoDataset(base_path, ["test"])
val_dataset = ASLVideoDataset(base_path, ["val"])

# Create DataLoaders
train_loader = DataLoader(train_dataset, batch_size=8, shuffle=True, num_workers=4)
test_loader = DataLoader(test_dataset, batch_size=8, shuffle=False, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=8, shuffle=False, num_workers=4)

# %% [markdown]
# # 3D cnn

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class C3DModel(nn.Module):
    def __init__(self, num_classes):
        super(C3DModel, self).__init__()
        self.conv1 = nn.Conv3d(3, 64, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool3d(kernel_size=2, stride=2)

        self.conv2 = nn.Conv3d(64, 128, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool3d(kernel_size=2, stride=2)

        self.conv3a = nn.Conv3d(128, 256, kernel_size=3, stride=1, padding=1)
        self.conv3b = nn.Conv3d(256, 256, kernel_size=3, stride=1, padding=1)
        self.pool3 = nn.MaxPool3d(kernel_size=2, stride=2)

        self.fc1 = nn.Linear(256 * 4 * 4 * 2, 4096)  # Adjust dimensions based on your input size
        self.fc2 = nn.Linear(4096, 4096)
        self.fc3 = nn.Linear(4096, num_classes)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)

        x = F.relu(self.conv2(x))
        x = self.pool2(x)

        x = F.relu(self.conv3a(x))
        x = F.relu(self.conv3b(x))
        x = self.pool3(x)

        x = x.view(x.size(0), -1)  # Flatten
        x = F.relu(self.fc1(x))
        x = F.dropout(x, 0.5)
        x = F.relu(self.fc2(x))
        x = F.dropout(x, 0.5)
        x = self.fc3(x)

        return x

# %% [markdown]
# BI DIRECTONAL LSTM

# %%
class BiLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes, num_layers=2):
        super(BiLSTMModel, self).__init__()
        self.lstm = nn.LSTM(
            input_size, hidden_size, num_layers, batch_first=True, bidirectional=True
        )
        self.fc = nn.Linear(hidden_size * 2, num_classes)

    def forward(self, x):
        # x shape: (batch_size, seq_len, input_size)
        out, _ = self.lstm(x)  # LSTM output
        out = out[:, -1, :]  # Take the output of the last time step
        out = self.fc(out)  # Fully connected layer
        return out

# %%
from torch.nn import TransformerEncoder, TransformerEncoderLayer

class VideoTransformer(nn.Module):
    def __init__(self, num_patches, embed_dim, num_heads, num_classes, num_layers=4):
        super(VideoTransformer, self).__init__()
        self.embedding = nn.Linear(num_patches, embed_dim)
        encoder_layer = TransformerEncoderLayer(embed_dim, num_heads)
        self.transformer_encoder = TransformerEncoder(encoder_layer, num_layers)
        self.fc = nn.Linear(embed_dim, num_classes)

    def forward(self, x):
        # x shape: (batch_size, num_frames, num_patches)
        x = self.embedding(x)  # Convert to embeddings
        x = self.transformer_encoder(x)  # Transformer Encoder
        x = x.mean(dim=1)  # Global average pooling
        x = self.fc(x)  # Fully connected layer
        return x

# %%
output = F.softmax(model_output, dim=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 output = F.softmax(model_output, dim=1)
#
# NameError: name 'model_output' is not defined

# %%
import torch.nn.functional as F

class EnsembleModel:
    def __init__(self, models):
        self.models = models  # List of trained models

    def predict(self, inputs):
        predictions = []
        for model in self.models:
            model.eval()
            with torch.no_grad():
                output = model(inputs)  # Get model output
                probabilities = F.softmax(output, dim=1)  # Convert to probabilities
                predictions.append(probabilities)
        
        # Average predictions
        ensemble_output = torch.mean(torch.stack(predictions), dim=0)
        return ensemble_output

# %%
# Instantiate the models
c3d_model = C3DModel(num_classes=num_classes).to(device)
bilstm_model = BiLSTMModel(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes).to(device)
transformer_model = VideoTransformer(num_patches=num_patches, embed_dim=embed_dim, num_heads=num_heads, num_classes=num_classes).to(device)

# Load trained model weights
c3d_model.load_state_dict(torch.load("c3d_model.pth"))
bilstm_model.load_state_dict(torch.load("bilstm_model.pth"))
transformer_model.load_state_dict(torch.load("transformer_model.pth"))

# Create the ensemble
ensemble = EnsembleModel(models=[c3d_model, bilstm_model, transformer_model])

# Predict on test data
for inputs, labels in test_loader:
    inputs = inputs.to(device)
    ensemble_output = ensemble.predict(inputs)
    predicted_labels = torch.argmax(ensemble_output, dim=1)
    print(f"Predictions: {predicted_labels}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Instantiate the models
# ----> 2 c3d_model = C3DModel(num_classes=num_classes).to(device)
#       3 bilstm_model = BiLSTMModel(input_size=input_size, hidden_size=hidden_size, num_classes=num_classes).to(device)
#       4 transformer_model = VideoTransformer(num_patches=num_patches, embed_dim=embed_dim, num_heads=num_heads, num_classes=num_classes).to(device)
#
# NameError: name 'num_classes' is not defined
